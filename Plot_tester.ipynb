# %%
from MicFileTool import MicFile

# %%
a=MicFile('395z0.mic.LBFS')
# Out:
# -0.545625 -0.535853 0 2 7 0 331.564 89.2068 26.2019 0 0.905184 0 0 1 1 1 0 0 0
#
# <type 'str'>
# sw is 1.44
#
# shape of snp is (22034, 19)

# %%
a.plot_mic_patches(2,minConfidence=0.35)

# %%
a.plot_mic_patches(1,minConfidence=0.35)
# Out:
# Current rod values:  [[ 0.87641654 -0.45271945 -0.01949867]
#  [ 0.61548644 -0.27515217  0.11883478]
#  [ 0.43584443  0.4214601  -0.23910525]
#  ...,
#  [ 0.98198114  0.19042073  0.07045825]
#  [ 0.39820235  0.58265212 -0.03000947]
#  [ 0.24569541  0.53337439  0.09331557]]
# Color:  [[ 0.93820827  0.27364027  0.49025066]
#  [ 0.80774322  0.36242391  0.55941739]
#  [ 0.71792221  0.71073005  0.38044738]
#  ...,
#  [ 0.99099057  0.59521036  0.53522913]
#  [ 0.69910117  0.79132606  0.48499527]
#  [ 0.6228477   0.7666872   0.54665779]]
